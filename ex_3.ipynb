# %% [markdown]
# <a href="https://colab.research.google.com/github/ErfanS99/python_course_SRBIAU/blob/main/ex_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
height = input("ENter the triangle height: ")
height = int(height)
for i in range(height):
  print("#"*(i+1))
# Out:
# ENter the triangle height: 5
# #
# ##
# ###
# ####
# #####

# %%
height = input("Enter the triangle height: ")
height = int(height)
for i in range(height):
  row = ""
  for _ in range(height - (i+1)):
    row = row + " "
  for _ in range((2 * i) + 1):
    row += "#"
  print(row)
# Out:
# Enter the triangle height: 5
#     #
#    ###
#   #####
#  #######
# #########

# %%
height = input("Enter the triangle height: ")
height = int(height)
for i in range(height):
  num_space = height - (i+1)
  num_tags = (2 * i) + 1
  print(" " * num_space + "#" * num_tags)
# Out:
# Enter the triangle height: 5
#     #
#    ###
#   #####
#  #######
# #########

# %%
while True:
  height = input("Enter the triangle height: ")

  if height[0].isalpha() or height[-1].isalpha():
    print("Invalid input")
    continue
  elif "." in height:
    print("An integer number should be entered")
    continue
  elif int(height) <= 0:
    print("Number should be greater than zero")
    continue
  else:
    height = int(height)
    for i in range(height):
      num_space = height - (i+1)
      num_tags = (2 * i) + 1
      print(" " * num_space + "#" * num_tags)
    break
# Out:
# Enter the triangle height: AsdfaDSF55
# Invalid input
# Enter the triangle height: -5
# Number should be greater than zero
# Enter the triangle height: 0
# Number should be greater than zero
# Enter the triangle height: 5.5
# An integer number should be entered
# Enter the triangle height: 5
#     #
#    ###
#   #####
#  #######
# #########

# %%
while True:
  try:
    height = int(input("Enter the triangle height: "))
    print("Code is ok!")
    break
  except ValueError:
    print("Invalid input")
    continue
# Out:
# Enter the triangle height: asdas51
# Invalid input
# Enter the triangle height: asd5515asd
# Invalid input
# Enter the triangle height: 5
# Code is ok!

# %%
int("asd")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2602370654.py in <cell line: 0>()
# ----> 1 int("asd")
#
# ValueError: invalid literal for int() with base 10: 'asd'

# %%
def myFunc( x: int ,y = 0):
  """
  Explanation about the function
  """
  z = x**2
  return [y, z]

# %%
a = myFunc(2,5) #  [a , b] = myFunc(2)
b = myFunc(2)

# %% [markdown]
# Modules

# %%
from math import sqrt     # Import a specific function from the module
from math import *        # Imports all the functions in the module
import numpy as np

# %%
sqrt(4)
pow(2,3)
exp(np.log(1))
np.round(5.4163165451,3)
# x = np.logspace(0,5,10)
x = np.linspace(0,5,100)
y = np.sin(np.pi*x)
# y

# %%
import matplotlib.pyplot as plt

# %%
# plt.plot(x,y, "r--")
plt.plot(x,y, marker = "o",markersize = 5)
plt.xlabel("X label")
plt.ylabel("alpha label")
plt.grid()
plt.show()
