# %% [markdown]
# <a href="https://colab.research.google.com/github/ErfanS99/python_course_SRBIAU/blob/main/Python_Exersices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise 1 — Count vowels
# Write a function `count_vowels(s)` that returns how many vowels appear in `s`.
# Edge cases to consider: empty string, uppercase letters, non-letters.

# %%
def count_vowels(s: str) -> int:
    # TODO: implement — start simple, then refine
    # Tip: consider a set of vowels and loop over characters
    pass

# %%
# 🔍 Debugging aid (you can add prints as you build):
print('Debug: running basic checks for count_vowels...')
assert count_vowels('hello') == 2
assert count_vowels('HELLO') == 2
assert count_vowels('xyz') == 0
assert count_vowels('') == 0
print('✓ count_vowels basic tests passed')

# %% [markdown]
# ## Exercise 2 — Reverse string (no slicing)
# Implement `reverse_manual(s)` **without** using slicing `s[::-1]`.

# %%
def reverse_manual(s: str) -> str:
    # TODO: implement without using slicing
    pass

# %%
print('Debug: running basic checks for reverse_manual...')
assert reverse_manual('abc') == 'cba'
assert reverse_manual('') == ''
assert reverse_manual('a') == 'a'
print('✓ reverse_manual basic tests passed')

# %% [markdown]
# ## Exercise 3 — Second Largest (Scanning)
# Return the **second largest** distinct number in a list.
# If it doesn't exist (e.g., all numbers equal or list < 2 distinct values), return `None`.

# %%
from typing import List, Optional

def second_largest(nums: List[int]) -> Optional[int]:
    # TODO: one pass scanning solution (track top1, top2)
    pass

# %%
print('Testing second_largest...')
assert second_largest([1,2,3]) == 2
assert second_largest([3,3,3]) is None
assert second_largest([10]) is None
assert second_largest([5,1,5,2]) == 2
print('✓ second_largest tests passed')

# %% [markdown]
# ## Exercise 4 — Remove Duplicates (No `set()`)
# Return a new list with the first occurrence of each element preserved.

# %%
def dedup_stable(xs):
    # TODO: preserve order, avoid set()
    pass

# %%
print('Testing dedup_stable...')
assert dedup_stable([1,1,2,3,2,1]) == [1,2,3]
assert dedup_stable([]) == []
assert dedup_stable(['a','a','b']) == ['a','b']
print('✓ dedup_stable tests passed')

# %% [markdown]
# ## Exercise 5 — Palindrome (Two Pointers)
# Check if a string is a palindrome, ignoring case and non-alphanumerics.

# %%
def is_palindrome(s: str) -> bool:
    # TODO: two-pointer technique
    pass

# %%
print('Testing is_palindrome...')
assert is_palindrome('A man, a plan, a canal: Panama') is True
assert is_palindrome('race a car') is False
assert is_palindrome('') is True
print('✓ is_palindrome tests passed')

# %% [markdown]
# ## Exercise 6 — Most Frequent Character (Frequency Map)
# Return the character with highest frequency; break ties by earliest appearance.

# %%
def most_frequent_char(s: str):
    # TODO: dict counting + tiebreak by first index
    pass

# %%
print('Testing most_frequent_char...')
assert most_frequent_char('abbccc') == 'c'
assert most_frequent_char('aab') == 'a'
assert most_frequent_char('') is None
print('✓ most_frequent_char tests passed')

# %% [markdown]
# ## Exercise 7 — Roman Numerals
# Implement two functions: `roman_to_int(s)` and `int_to_roman(n)` for 1 ≤ n ≤ 3999.

# %%
def roman_to_int(s: str) -> int:
    # TODO
    pass

def int_to_roman(n: int) -> str:
    # TODO
    pass

# %%
print('Testing Roman conversions...')
pairs = [(1,'I'),(4,'IV'),(9,'IX'),(58,'LVIII'),(1994,'MCMXCIV'),(3999,'MMMCMXCIX')]
for val, rn in pairs:
    assert int_to_roman(val) == rn
    assert roman_to_int(rn) == val
print('✓ Roman numeral tests passed')

# %% [markdown]
# ## Exercise 8 — Re-implement `max()`
# Write `my_max(iterable, key=None)` that mimics built-in `max` for non-empty iterables.
# Raise `ValueError` on empty input (like `max`).

# %%
def my_max(iterable, key=None):
    # TODO
    pass

# %%
print('Testing my_max...')
assert my_max([1,2,3]) == 3
assert my_max(['a','bbb','cc'], key=len) == 'bbb'
try:
    my_max([])
    raise AssertionError('Empty iterable should raise ValueError')
except ValueError:
    pass
print('✓ my_max tests passed')

# %% [markdown]
# ## Exercise 9 — Tiny Calculator
# Implement `calc(expr: str) -> int|float` to evaluate expressions with +, -, *, / and parentheses.
# Constraint: **Do not** use `eval`. You may parse tokens then use a stack-based approach (Shunting-yard).

# %%
def calc(expr: str):
    # TODO: tokenization + shunting-yard or two-stack eval
    pass

# %%
# Quick sanity tests for calc (non-exhaustive):
print('Testing calc...')
tests = {
    '1+2*3': 7,
    '(1+2)*3': 9,
    '10/2+3*2': 11,
    '8-3-2': 3,
}
for expr, expected in tests.items():
    try:
        out = calc(expr)
        assert out == expected, (expr, out, expected)
    except NotImplementedError:
        pass
print('✓ calc sanity tests executed (implement to pass)')
